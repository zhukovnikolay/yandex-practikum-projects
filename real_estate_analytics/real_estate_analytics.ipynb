# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Признак-ceiling_height" data-toc-modified-id="Признак-ceiling_height-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Признак ceiling_height</a></span></li><li><span><a href="#Признак-floors_total" data-toc-modified-id="Признак-floors_total-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Признак floors_total</a></span></li><li><span><a href="#Признак-living_area" data-toc-modified-id="Признак-living_area-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Признак living_area</a></span></li><li><span><a href="#Признак-is_apartment" data-toc-modified-id="Признак-is_apartment-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Признак is_apartment</a></span></li><li><span><a href="#Признак-kitchen_area" data-toc-modified-id="Признак-kitchen_area-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Признак kitchen_area</a></span></li><li><span><a href="#Признак-balcony" data-toc-modified-id="Признак-balcony-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Признак balcony</a></span></li><li><span><a href="#Признак-locality_name" data-toc-modified-id="Признак-locality_name-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Признак locality_name</a></span></li><li><span><a href="#Остальные-признаки" data-toc-modified-id="Остальные-признаки-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Остальные признаки</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Результаты-предобработки-данных" data-toc-modified-id="Результаты-предобработки-данных-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Результаты предобработки данных</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-площади,-цены,-числа-комнат,-высоты-потолков." data-toc-modified-id="Изучение-площади,-цены,-числа-комнат,-высоты-потолков.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Изучение площади, цены, числа комнат, высоты потолков.</a></span><ul class="toc-item"><li><span><a href="#Площадь" data-toc-modified-id="Площадь-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Площадь</a></span></li><li><span><a href="#Цена" data-toc-modified-id="Цена-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Цена</a></span></li><li><span><a href="#Число-комнат" data-toc-modified-id="Число-комнат-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Число комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Высота потолков</a></span></li></ul></li><li><span><a href="#Изучаем-время-продажи-квартиры." data-toc-modified-id="Изучаем-время-продажи-квартиры.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Изучаем время продажи квартиры.</a></span></li><li><span><a href="#Работаем-с-аномалиями" data-toc-modified-id="Работаем-с-аномалиями-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Работаем с аномалиями</a></span></li><li><span><a href="#Факторы,-влияющие-на-стоимость-квартиры" data-toc-modified-id="Факторы,-влияющие-на-стоимость-квартиры-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Факторы, влияющие на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Зависимость-цены-от-площади" data-toc-modified-id="Зависимость-цены-от-площади-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Зависимость цены от площади</a></span></li><li><span><a href="#Зависимость-цены-от-числа--комнат" data-toc-modified-id="Зависимость-цены-от-числа--комнат-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>Зависимость цены от числа  комнат</a></span></li><li><span><a href="#Зависимость-цены-от-удаленности-от-центра" data-toc-modified-id="Зависимость-цены-от-удаленности-от-центра-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>Зависимость цены от удаленности от центра</a></span></li><li><span><a href="#Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом." data-toc-modified-id="Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-5.4.4"><span class="toc-item-num">5.4.4&nbsp;&nbsp;</span>Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.</a></span></li><li><span><a href="#Зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-5.4.5"><span class="toc-item-num">5.4.5&nbsp;&nbsp;</span>Зависимость от даты размещения: дня недели, месяца и года.</a></span></li><li><span><a href="#Общий-вывод-по-подразделу" data-toc-modified-id="Общий-вывод-по-подразделу-5.4.6"><span class="toc-item-num">5.4.6&nbsp;&nbsp;</span>Общий вывод по подразделу</a></span></li></ul></li><li><span><a href="#10-населённых-пунктов-с-наибольшим-числом-объявлений-(определение-населенных-пунктов-с-дорогим-и-дешевым-жильем)" data-toc-modified-id="10-населённых-пунктов-с-наибольшим-числом-объявлений-(определение-населенных-пунктов-с-дорогим-и-дешевым-жильем)-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>10 населённых пунктов с наибольшим числом объявлений (определение населенных пунктов с дорогим и дешевым жильем)</a></span></li><li><span><a href="#Определение-границ-центра-Санкт-Петербурга" data-toc-modified-id="Определение-границ-центра-Санкт-Петербурга-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Определение границ центра Санкт-Петербурга</a></span></li><li><span><a href="#Анализ-квартир-в-центре-города" data-toc-modified-id="Анализ-квартир-в-центре-города-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Анализ квартир в центре города</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров" data-toc-modified-id="Изучение-параметров-5.7.1"><span class="toc-item-num">5.7.1&nbsp;&nbsp;</span>Изучение параметров</a></span></li><li><span><a href="#Факторы,-которые-влияют-на-стоимость-квартиры" data-toc-modified-id="Факторы,-которые-влияют-на-стоимость-квартиры-5.7.2"><span class="toc-item-num">5.7.2&nbsp;&nbsp;</span>Факторы, которые влияют на стоимость квартиры</a></span></li><li><span><a href="#Вывод-по-подразделу" data-toc-modified-id="Вывод-по-подразделу-5.7.3"><span class="toc-item-num">5.7.3&nbsp;&nbsp;</span>Вывод по подразделу</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Описание данных
# Для удобства
#
#     airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
#     balcony — число балконов
#     ceiling_height — высота потолков (м)
#     cityCenters_nearest — расстояние до центра города (м)
#     days_exposition — сколько дней было размещено объявление (от публикации до снятия)
#     first_day_exposition — дата публикации
#     floor — этаж
#     floors_total — всего этажей в доме
#     is_apartment — апартаменты (булев тип)
#     kitchen_area — площадь кухни в квадратных метрах (м²)
#     last_price — цена на момент снятия с публикации
#     living_area — жилая площадь в квадратных метрах (м²)
#     locality_name — название населённого пункта
#     open_plan — свободная планировка (булев тип)
#     parks_around3000 — число парков в радиусе 3 км
#     parks_nearest — расстояние до ближайшего парка (м)
#     ponds_around3000 — число водоёмов в радиусе 3 км
#     ponds_nearest — расстояние до ближайшего водоёма (м)
#     rooms — число комнат
#     studio — квартира-студия (булев тип)
#     total_area — площадь квартиры в квадратных метрах (м²)
#     total_images — число фотографий квартиры в объявлении

# %% [markdown]
# ## Изучение данных из файла

# %%
# импортируем библиотеки
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
# убираем предупреждения
warnings.filterwarnings("ignore")

# %%
# снимаем ограничение на вывод количества столбцов, чтобы видеть все данные
pd.set_option('display.max_columns', None)

# %%
# считываем данные
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
# посмотрим общую информацию о данных
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# Видим первые особенности данных:
# 1. В существенном числе признаков (фактически их нет только в признаках total_images, last_price, total_area, first_day_exposition, rooms, floor, studio, open_plan) есть пропуски. Где-то их количество незначительно (например, "floors_total"), а где-то больше, чем доступных данных (например, "is_apartment").
# 2. Типы данных в некоторых признаках не выглядят корректными: first_day_exposition (потребуется перевод в datetime), floors_total (судя по описанию данных, нужен тип int), is_apartment (нужен тип bool), balcony (нужен тип int), parks_around3000 (нужен тип int), ponds_around3000 (нужен тип int), days_exposition (также тип int).
# 3. В признаке cityCenters_nearest не используется snake_case. Переименуем его.
#
# Также можно было бы оптимизировать используемое в памяти место (типы float64, int64 выглядят избыточными по описанию данных).

# %%
# посмотрим на данные глазами
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Видим, что помимо упомянутых выше, на первый взгляд можно было бы поменять тип для признаков last_price, parks_nearest, ponds_nearest, cityCenters_nearest (дробная часть чисел отсутствует + на достаточно большой размерности не сыграла бы особой роли для анализа) - проверим это позже.

# %%
# посмотрим статистическую информацию о данных
data.describe().T
# Out:
#                        count          mean           std      min         25%  \
# total_images         23699.0  9.858475e+00  5.682529e+00      0.0        6.00
# last_price           23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.00
# total_area           23699.0  6.034865e+01  3.565408e+01     12.0       40.00
# rooms                23699.0  2.070636e+00  1.078405e+00      0.0        1.00
# ceiling_height       14504.0  2.771499e+00  1.261056e+00      1.0        2.52
# floors_total         23613.0  1.067382e+01  6.597173e+00      1.0        5.00
# living_area          21796.0  3.445785e+01  2.203045e+01      2.0       18.60
# floor                23699.0  5.892358e+00  4.885249e+00      1.0        2.00
# kitchen_area         21421.0  1.056981e+01  5.905438e+00      1.3        7.00
# balcony              12180.0  1.150082e+00  1.071300e+00      0.0        0.00
# airports_nearest     18157.0  2.879367e+04  1.263088e+04      0.0    18585.00
# ...

# %% [markdown]
# Опишем особенности (проблемы) признаков:
# - last_price: подозрительно маленькое минимальное значение и достаточно большое максимальное (проверим на наличие частных домов в данных, в изначальном описании речь шла только про квартиры).
# - total_area: тоже достаточно низкое минимальное значение (хотя сейчас есть и настолько маленькие студии / комнаты в коммунальных квартирах), а также достаточно большое максимальное (особенно, если в данных нет частных домов) - потребуется дополнительная проверка (особенно с учетом достаточно высокого стандартного отклонения).
# - rooms: с учетом наличия в данных студий к минимальному значению вопросов нет, максимальное требует дополнительного анализа.
# - ceiling_height: минимальное значение 1 м - землянка какая-то, максимальное значение 100 м - высоковато для потолка.
# - floors_total: максимальное значение 60 - беглый поиск по Интернету показал, что максимальная этажность ЖК в Петербурге - 35 этажей.
# - living_area: минимальное значение (2 м) кажется некорректным даже для 12-метровой студии, максимальное видимо также относится к частному сектору.
# - floor: с некоторыми допусками данные тут могут быть корректны.
# - kitchen_area: и минимальные, и максимальные значения выглядят плохо.
# - balcony: максимально 5 балконов, допустим.
# - airports_nearest: минимальное значение 0 м, максимальное 85 км - проверим.
# - cityCenters_nearest: смущает максимальное значение в почти 66 км (указано, что помимо Питера в выборке есть и ближайшие населенные пункты - если они так далеко, а считается все от центра Петербурга, то может быть с данными все в порядке).
# - parks_nearest, ponds_nearest: достаточно низкие минимальные значения.
# - days_exposition: очень большое максимальное значение (объект в продаже 4 с лишним года).

# %%
# отдельно оценим частотность категориальных признаков
cat_feats = ['is_apartment', 'studio', 'open_plan', 'locality_name']
for column in cat_feats:
    print(column + '\n\n' + str(data[column].value_counts(dropna=False)) + '\n' + '*' * 100 + '\n')
# Out:
# is_apartment
#
# NaN      20924
# False     2725
# True        50
# Name: is_apartment, dtype: int64
# ****************************************************************************************************
#
# studio
#
# False    23550
# True       149
# Name: studio, dtype: int64
# ****************************************************************************************************
#
# open_plan
#
# False    23632
# True        67
# Name: open_plan, dtype: int64
# ****************************************************************************************************
#
# locality_name
#
# Санкт-Петербург                   15721
# посёлок Мурино                      522
# посёлок Шушары                      440
# Всеволожск                          398
# Пушкин                              369
#                                   ...
# деревня Шпаньково                     1
# поселок городского типа Рябово        1
# поселок Каложицы                      1
# ...

# %% [markdown]
# Видим существенный дисбаланс в категориях is_apartment, studio, open_plan. В признаке is_apartment также существенное число пропусков.
#
# В категории locality_name есть много данных для Санкт-Петербурга и, судя по всему, много данных для достаточно маленьких населенных пунктов (всего 364 разных населенных пункта в признаке), которые впоследствии придется сгруппировать в одну категорию.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Мы обнаружили, что в существенной части данных (в 14 из 22 признаков) есть пропуски, причем в некоторых признаках (например, park_nearest, is_apartment и т.д.) число пропусков больше числа заполненных значений.
# 2. У части признаков некорректные типы (в основном требуется замена float на int).
# 3. Имя переменной cityCenters_nearest нужно привести к snake_case.
# 4. Почти все признаки требуют дополнительного исследования ввиду наличия слишком малых и/или слишком больших значений.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Подготовим функции для дальнейшего анализа данных

# %%
# функция построения гистограммы с медианой, средним и модой
def my_hist(data, column, bins=10):
    feat_median = data[column].median()
    feat_mean = data[column].mean()
    feat_mode = data[column].mode()[0]
    fig, ax = plt.subplots(figsize=(12, 6))
    ax.hist(data[column], bins=bins)
    ax.set_title(column)
    ax.axvline(feat_median, color='g', linestyle='--', label='медиана')
    ax.axvline(feat_mean, color='r', linestyle='--', label='среднее')
    ax.axvline(feat_mode, color='y', linestyle='--', label='мода')
    ax.legend()
    plt.show()

# %%
# функция, позволяющая исследовать признак
def feature_stat(data, column, need_hist=False, hist_bins=10, print_low=False, print_high=False, print_nan=False):
    missed_count = data[column].isna().sum()
    feat_mode = data[column].mode()[0]
    feat_stats = data[column].describe()
    if data[column].dtype not in ['object', 'bool']:
        print(f'Признак {column}\n{100 * "_"}\n'
              f'Кол-во пропусков (доля): {missed_count} ({missed_count / data.shape[0]:.1%})\n'
              f'Кол-во уникальных значений: {data[column].nunique()}\n'
              f'Минимальное значение: {feat_stats["min"]}\n'
              f'Максимальное значение: {feat_stats["max"]}\n'
              f'Медиана: {feat_stats["50%"]}\n'
              f'Среднее: {feat_stats["mean"]}\n'
              f'Мода: {feat_mode}\n'
              f'Тип данных: {data[column].dtype}\n' + 100 * '_')
    else:
        print(f'Признак {column}\n{100 * "_"}\n'
              f'Кол-во пропусков (доля): {missed_count} ({missed_count / data.shape[0]:.1%})\n'
              f'Кол-во уникальных значений: {data[column].nunique()}\n'
              f'Мода: {feat_mode}\n'
              f'Тип данных: {data[column].dtype}\n' + 100 * '_')
    if need_hist:
        print('Гистограмма')
        my_hist(data, column, bins=hist_bins)
        print(100 * '_')
    if print_low:
        print(f'Пять самых низких значений')
        display(data.sort_values(column).head(5))
        print(100 * '_')
    if print_high:
        print(f'Пять самых высоких значений')
        display(data.sort_values(column, ascending=False).head(5))
        print(100 * '_')
    if print_nan:
        print(f'Пять случайных объектов с пропусками')
        try:
            display(data[data[column].isna()].sample(5))
        except:
            print('При выполнении произошла ошибка. Возможно, в данных нет пропусков')
        print(100 * '_')

# %% [markdown]
# По условиям задания в данном разделе требуется только заполнить пропуски и исправить типы данных, хотя корректнее было бы проводить заполнение пропусков одновременно с обработкой аномалий в данных, иначе заполнение может быть некорректным (при большом числе аномалий).
#
# Однако будем следовать условию задания.

# %%
# формируем список признаков с пропусками
features_list_with_nan = []
for feature in data.columns:
    if data[feature].isna().sum() != 0:
        features_list_with_nan.append(feature)
features_list_with_nan
# Out:
# ['ceiling_height',
#  'floors_total',
#  'living_area',
#  'is_apartment',
#  'kitchen_area',
#  'balcony',
#  'locality_name',
#  'airports_nearest',
#  'cityCenters_nearest',
#  'parks_around3000',
#  'parks_nearest',
#  'ponds_around3000',
#  'ponds_nearest',
#  'days_exposition']

# %% [markdown]
# Займемся обработкой пропусков в признаках по очереди.

# %% [markdown]
# ### Признак ceiling_height

# %%
# смотрим статистику по признаку
feature_stat(data, 'ceiling_height', print_nan=True)
# Out:
# Признак ceiling_height
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 9195 (38.8%)
# Кол-во уникальных значений: 183
# Минимальное значение: 1.0
# Максимальное значение: 100.0
# Медиана: 2.65
# Среднее: 2.77149889685604
# Мода: 2.5
# Тип данных: float64
# ____________________________________________________________________________________________________
# Пять случайных объектов с пропусками
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1515              6   2500000.0        46.0  2017-04-18T00:00:00      2
# 22639            13   3450000.0        50.0  2017-01-20T00:00:00      2
# 20797             6   3690000.0        42.0  2016-04-18T00:00:00      2
# 20953             3   8500000.0        86.8  2018-10-19T00:00:00      3
# 14119             3   9000000.0        45.1  2018-01-01T00:00:00      1
#
# ...

# %% [markdown]
# В признаке достаточно много пропущенных значений (38.8%), и явно есть аномалии в малых и больших значениях (1 и 100 м соответственно). Логичнее всего предположить, что пропуски появились из-за необязательности заполнения данного поля при размещении объявлений из-за отсутствия у собственников точных данных.
#
# Простое заполнение медианой с учетом большого числа пропусков приведет к сильному перекосу в сторону медианного значения. Возможно, наиболее оптимальным было бы исключить данный признак, чтобы большое количество неподтвержденных значений не повлияло на результат анализа.
#
# Можно предположить, что высота потолков зависит от года постройки дома, но таких данных у нас нет (можно было бы попробовать установить возраст дома через признак floors_total - более старые здания в общем случае имеют меньшую этажность и меньшие потолки (впрочем, что совсем неочевидно для Петербурга)).
#
# Проверим наше предположение через коэффициент корреляции Пирсона.

# %%
data[['floors_total', 'ceiling_height']].corr()
# Out:
#                 floors_total  ceiling_height
# floors_total        1.000000       -0.028732
# ceiling_height     -0.028732        1.000000

# %% [markdown]
# Признаки практически не коррелируют, предположение не подтвердилось.
#
# Заполним пока пропуски медианой, но введем дополнительный признак-флаг о том, что в данных были пропуски.

# %%
data['ceiling_height_nan_flag'] = 0
data.loc[data['ceiling_height'].isna(), 'ceiling_height_nan_flag'] = 1
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %%
# смотрим статистику по признаку
feature_stat(data, 'ceiling_height', print_nan=True)
# Out:
# Признак ceiling_height
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 183
# Минимальное значение: 1.0
# Максимальное значение: 100.0
# Медиана: 2.65
# Среднее: 2.724358411747331
# Мода: 2.65
# Тип данных: float64
# ____________________________________________________________________________________________________
# Пять случайных объектов с пропусками
# При выполнении произошла ошибка. Возможно, в данных нет пропусков
# ____________________________________________________________________________________________________

# %% [markdown]
# Пропусков больше нет.

# %%
data.head(3)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1            2.65          11.0         18.6      1          NaN   False
# 2            2.65           5.0         34.3      4          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 0      False          25.0      NaN  Санкт-Петербург           18863.0
# 1      False          11.0      2.0   посёлок Шушары           12817.0
# 2      False           8.3      0.0  Санкт-Петербург           21741.0
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# ...

# %% [markdown]
# Заполнение прошло корректно.

# %% [markdown]
# ### Признак floors_total

# %%
# смотрим статистику по признаку
feature_stat(data, 'floors_total', print_nan=True)
# Out:
# Признак floors_total
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 86 (0.4%)
# Кол-во уникальных значений: 36
# Минимальное значение: 1.0
# Максимальное значение: 60.0
# Медиана: 9.0
# Среднее: 10.67382374115953
# Мода: 5.0
# Тип данных: float64
# ____________________________________________________________________________________________________
# Пять случайных объектов с пропусками
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5784              4   4262941.0       59.90  2017-04-02T00:00:00      2
# 10983             6   4670000.0       37.80  2019-03-13T00:00:00      1
# 10058             9   3350000.0       25.00  2018-09-10T00:00:00      1
# 5146             10   3085024.0       33.33  2018-10-06T00:00:00      1
# 20146            16   3850000.0       36.00  2018-10-12T00:00:00      1
#
# ...

# %% [markdown]
# Пропусков достаточно мало (0.4%), однако получить данную информацию нам неоткуда. Причина появления пропусков вероятно аналогична предыдущему признаку (данные не указаны при создании объявления), однако может быть вызвана и некорретной выгрузкой данных из какой-либо базы жилых домов.
#
# Следует учитывать, что от данного признака может зависеть потенциальная оценка недвижимости (т.к. если окажется, что этаж первый или последний, цена квартиры будет ниже - неоднозначно для лофтов). Разумнее всего выглядит работа по одному из двух вариантов:
# 1. Исключение объектов с пропусками - на результат анализа это сильно не повлияет ввиду малочисленности пропусков.
# 2. Заполнение пропусков максимальным из двух значений (медианой по всем данным (или локации) или данными из признака floor (тогда максимальный этаж будет равен этажу объекта недвижимости)).
#
# Попробуем сохранить данные, заполнив пропуски.

# %%
data['floors_total_nan_flag'] = 0
data.loc[data['floors_total'].isna(), 'floors_total_nan_flag'] = 1
data.loc[data['floors_total'].isna(), 'floors_total'] = data.apply(lambda x: max(x['floor'], data['floors_total'].median()), axis=1)

# %%
# смотрим статистику по признаку
feature_stat(data, 'floors_total', print_nan=True)
# Out:
# Признак floors_total
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 36
# Минимальное значение: 1.0
# Максимальное значение: 60.0
# Медиана: 9.0
# Среднее: 10.67867842525001
# Мода: 5.0
# Тип данных: float64
# ____________________________________________________________________________________________________
# Пять случайных объектов с пропусками
# При выполнении произошла ошибка. Возможно, в данных нет пропусков
# ____________________________________________________________________________________________________

# %% [markdown]
# Пропусков больше нет. Посмотрим на данные, в которых были пропуски для оценки корректности заполнения.

# %%
data[data['floors_total_nan_flag'] == 1].head()
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 186             12  11640000.0        65.2  2018-10-02T00:00:00      2
# 237              4   2438033.0        28.1  2016-11-23T00:00:00      1
# 457              4   9788348.0        70.8  2015-08-01T00:00:00      2
# 671              4   6051191.0        93.6  2017-04-06T00:00:00      3
# 1757             5   3600000.0        39.0  2017-04-22T00:00:00      1
#
#       ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 186             2.65           9.0        30.80      4          NaN   False
# 237             2.65           9.0        20.75      1          NaN   False
# 457             2.65          12.0        38.40     12          NaN   False
# 671             2.65           9.0        47.10      8          NaN   False
# 1757            2.65           9.0          NaN      9          NaN   False
#
#       open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Заполнение проведено корректно.
#
# Поменяем тип данных на int.

# %%
data['floors_total'] = data['floors_total'].astype('int')

# %%
feature_stat(data, 'floors_total')
# Out:
# Признак floors_total
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 36
# Минимальное значение: 1.0
# Максимальное значение: 60.0
# Медиана: 9.0
# Среднее: 10.67867842525001
# Мода: 5
# Тип данных: int64
# ____________________________________________________________________________________________________

# %% [markdown]
# Тип данных изменен, работа с признаком на данном этапе окончена.

# %% [markdown]
# ### Признак living_area

# %%
# смотрим статистику по признаку
feature_stat(data, 'living_area', print_nan=True)
# Out:
# Признак living_area
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 1903 (8.0%)
# Кол-во уникальных значений: 1782
# Минимальное значение: 2.0
# Максимальное значение: 409.7
# Медиана: 30.0
# Среднее: 34.457852427601395
# Мода: 18.0
# Тип данных: float64
# ____________________________________________________________________________________________________
# Пять случайных объектов с пропусками
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 6758             13   1950000.0       44.60  2018-06-14T00:00:00      2
# 7662              4   8220312.0       80.12  2017-05-06T00:00:00      2
# 20712            10   2537830.0       36.00  2017-08-24T00:00:00      1
# 9745              6   3990000.0       33.65  2017-09-28T00:00:00      1
# 1307             20  26558000.0      152.38  2017-01-11T00:00:00      5
#
# ...

# %% [markdown]
# В данных есть некоторое количество пропусков (порядка 8%). Наиболее логичной причиной их появления является незаполненная информация при размещении объявления.
#
# При этом, наиболее корректным представляется заполнение пропущенных значений по среднему отношению общей площади (total_area) к жилой (living_area). Убедимся, что эти признаки коррелируют между собой.

# %%
data[['total_area', 'living_area']].corr()
# Out:
#              total_area  living_area
# total_area     1.000000     0.939537
# living_area    0.939537     1.000000

# %% [markdown]
# Коэффициент корреляции достаточно высок, поэтому данный способ заполнения представляется оптимальным.
#
# Вычислим отношение медиан жилой площади к общей по всем данным.

# %%
total_to_living_area_ratio = data['living_area'].median() / data['total_area'].median()
total_to_living_area_ratio
# Out:
# 0.5769230769230769

# %%
# заполним пропуски, округлив до второго знака после запятой
data['living_area_nan_flag'] = 0
data.loc[data['living_area'].isna(), 'living_area_nan_flag'] = 1
data.loc[data['living_area'].isna(), 'living_area'] = round(data['total_area'] * total_to_living_area_ratio, 2)

# %%
# смотрим статистику по признаку
feature_stat(data, 'living_area')
# Out:
# Признак living_area
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 2294
# Минимальное значение: 2.0
# Максимальное значение: 409.7
# Медиана: 30.0
# Среднее: 34.62429138410903
# Мода: 18.0
# Тип данных: float64
# ____________________________________________________________________________________________________

# %% [markdown]
# Пропусков больше нет. Посмотрим на данные, в которых были пропуски для оценки корректности заполнения.

# %%
data[data['living_area_nan_flag'] == 1].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0  64900000.0       159.0  2015-07-24T00:00:00      3
# 7              5   7915000.0        71.6  2019-04-18T00:00:00      2
# 30            12   2200000.0        32.8  2018-02-19T00:00:00      1
# 37            10   1990000.0        45.8  2017-10-28T00:00:00      2
# 44            13   5350000.0        40.0  2018-11-18T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 3             2.65            14        91.73      9          NaN   False
# 7             2.65            24        41.31     22          NaN   False
# 30            2.65             9        18.92      2          NaN   False
# 37            2.50             5        26.42      1          NaN   False
# 44            2.65            22        23.08      3          NaN   False
#
#     open_plan  kitchen_area  balcony                        locality_name  \
# ...

# %% [markdown]
# Заполнение выполнено корректно, тип данных менять не требуется, работ с признаком на данном этапе завершена.

# %% [markdown]
# ### Признак is_apartment

# %%
# смотрим статистику по признаку
feature_stat(data, 'is_apartment', print_nan=True)
# Out:
# Признак is_apartment
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 20924 (88.3%)
# Кол-во уникальных значений: 2
# Мода: False
# Тип данных: object
# ____________________________________________________________________________________________________
# Пять случайных объектов с пропусками
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 6720             10   2400000.0        40.4  2017-07-12T00:00:00      1
# 19637            11   8950000.0        73.0  2017-05-17T00:00:00      2
# 18667             8   3000000.0        44.4  2018-03-06T00:00:00      2
# 20056             4   1650000.0        54.0  2016-06-05T00:00:00      3
# 9594              3   8600000.0        65.0  2016-06-14T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 6720             2.52             5        17.07      3          NaN   False
# ...

# %%
# вспомним частотность данных
data['is_apartment'].value_counts(dropna=False)
# Out:
# NaN      20924
# False     2725
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# В данных очень много пропусков (более 88%), причина скорее всего все в том же незаполнении данных при размещении объявления. Продавцы обычных квартир скорее всего считают незаполнение данного поля автоматически подразумевающим, что недвижимость - не апартамент, у продавцов апартаментов, конечно, есть некоторые основания скрывать вид объекта недвижимости (апартаменты являются менее привлекательным объектом для большинства потенциальных покупателей (нежилое помещение - нельзя прописаться, более высокие налоги и коммуналка)), однако маловероятно, что таких продавцов достаточно много.
#
# С учетом сильного дисбаланса в сторону обычных квартир и учитывая возможную причину неуказания типа объекта недвижимости, приведенную выше, можно выбрать тактику заполнения пропусков модой.

# %%
# заполним пропуски
data['is_apartment_nan_flag'] = 0
data.loc[data['is_apartment'].isna(), 'is_apartment_nan_flag'] = 1
data.loc[data['is_apartment'].isna(), 'is_apartment'] = False

# %%
# изменим тип данных на bool
data['is_apartment'] = data['is_apartment'].astype('bool')

# %%
# смотрим статистику по признаку
feature_stat(data, 'is_apartment')
# Out:
# Признак is_apartment
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 2
# Мода: False
# Тип данных: bool
# ____________________________________________________________________________________________________

# %% [markdown]
# Пропусков больше нет, тип данных корректный.

# %% [markdown]
# ### Признак kitchen_area

# %%
# смотрим статистику по признаку
feature_stat(data, 'kitchen_area', print_nan=True)
# Out:
# Признак kitchen_area
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 2278 (9.6%)
# Кол-во уникальных значений: 971
# Минимальное значение: 1.3
# Максимальное значение: 112.0
# Медиана: 9.1
# Среднее: 10.569807198543485
# Мода: 6.0
# Тип данных: float64
# ____________________________________________________________________________________________________
# Пять случайных объектов с пропусками
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 199               4   3735325.0       37.40  2019-03-22T00:00:00      1
# 1890              4   3250000.0       33.50  2018-11-09T00:00:00      1
# 7700             10   3001767.0       35.29  2018-10-01T00:00:00      1
# 7888              1   1000000.0       31.40  2017-12-07T00:00:00      1
# 10929            13   9610305.0       61.00  2017-08-23T00:00:00      1
#
# ...

# %% [markdown]
# В данных есть некоторое количество пропусков (9.6%). Наиболее логичной причиной их появления является незаполненная информация при размещении объявления.
#
# Посмотрим, как коррелируют признаки total_area, kitchen_area и living_area.

# %%
data[['total_area', 'kitchen_area', 'living_area']].corr()
# Out:
#               total_area  kitchen_area  living_area
# total_area      1.000000      0.609121     0.946253
# kitchen_area    0.609121      1.000000     0.436372
# living_area     0.946253      0.436372     1.000000

# %% [markdown]
# Корреляция с признаком total_area выше, чем с living_area (0.6 против 0.43), но она не такая большая как у total_area с living_area, так что заполнение пропусков в kitchen_area по указанному методу будет менее точным. Отдельно стоит отметить, что заполнение пропусков только за счет признака total_area может привести к ситуации, когда total_area будет меньше суммы kitchen_area и living_area.
#
# Рассчитаем среднее отношение kitchen_area к total_area, а также разницу между total_area и living_area, для заполнения пропусков используем минимальное из двух этих значений.

# %%
total_to_kitchen_area_ratio = data['kitchen_area'].median() / data['total_area'].median()
total_to_kitchen_area_ratio
# Out:
# 0.175

# %%
# заполним пропуски, округлив до второго знака после запятой
data['kitchen_area_nan_flag'] = 0
data.loc[data['kitchen_area'].isna(), 'kitchen_area_nan_flag'] = 1
data.loc[data['kitchen_area'].isna(), 'kitchen_area'] = data.apply(lambda x: min(round(total_to_kitchen_area_ratio * x['total_area'], 2), 
                                                                                 x['total_area'] - x['living_area']),
                                                                   axis=1)

# %%
# смотрим статистику по признаку
feature_stat(data, 'kitchen_area')
# Out:
# Признак kitchen_area
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 1381
# Минимальное значение: 0.0
# Максимальное значение: 112.0
# Медиана: 9.0
# Среднее: 10.498350985020465
# Мода: 6.0
# Тип данных: float64
# ____________________________________________________________________________________________________

# %% [markdown]
# Пропусков больше нет.

# %%
data[data['kitchen_area_nan_flag'] == 1].head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0  64900000.0       159.0  2015-07-24T00:00:00      3
# 30            12   2200000.0        32.8  2018-02-19T00:00:00      1
# 37            10   1990000.0        45.8  2017-10-28T00:00:00      2
# 44            13   5350000.0        40.0  2018-11-18T00:00:00      1
# 59            15   6300000.0        46.5  2017-03-06T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 3             2.65            14        91.73      9         False   False
# 30            2.65             9        18.92      2         False   False
# 37            2.50             5        26.42      1         False   False
# 44            2.65            22        23.08      3         False   False
# 59            2.65            13        26.83     13         False   False
#
#     open_plan  kitchen_area  balcony                        locality_name  \
# ...

# %% [markdown]
# Заполнение выглядит корректным, тип данных тоже корректен, пока с данным признаком закончим.

# %% [markdown]
# ### Признак balcony

# %%
# смотрим статистику по признаку
feature_stat(data, 'balcony', print_nan=True)
# Out:
# Признак balcony
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 11519 (48.6%)
# Кол-во уникальных значений: 6
# Минимальное значение: 0.0
# Максимальное значение: 5.0
# Медиана: 1.0
# Среднее: 1.1500821018062397
# Мода: 1.0
# Тип данных: float64
# ____________________________________________________________________________________________________
# Пять случайных объектов с пропусками
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 17705            13   9900000.0       113.3  2018-10-17T00:00:00      3
# 16457            13   2800000.0        29.8  2019-01-21T00:00:00      1
# 21815             8   5100000.0        64.0  2017-07-18T00:00:00      2
# 16748             4   3305000.0        39.2  2018-10-01T00:00:00      1
# 16448             8   3700000.0        31.0  2017-10-25T00:00:00      1
#
# ...

# %% [markdown]
# В признаке достаточно много пропусков (48.6%), основная причина - незаполненные данные при размещении объявления, например, из-за отсутствия балконов в квартире. Посмотрим внимательнее на данные с пропусками.

# %%
# применяем, потому что уникальных значений всего 6
data['balcony'].value_counts()
# Out:
# 1.0    4195
# 0.0    3758
# 2.0    3659
# 5.0     304
# 4.0     183
# 3.0      81
# Name: balcony, dtype: int64

# %% [markdown]
# В большинстве квартир 1 балкон, что логично, хотя кол-во квартир без балконов или с двумя балконами также велико.
#
# Посмотрим среднее кол-во балконов в зависимости от этажа (предполагаем, что балконов в основном нет на 1 этаже).

# %%
data.pivot_table(index='floor', values='balcony').T
# Out:
# floor          1         2         3        4         5         6         7   \
# balcony  0.710394  0.964758  1.057161  1.05663  1.095445  1.303371  1.261972
#
# floor          8         9         10        11        12        13        14  \
# balcony  1.377451  1.247261  1.360494  1.433225  1.388715  1.369565  1.408163
#
# floor          15       16        17     18        19        20    21  \
# balcony  1.513636  1.40113  1.349206  1.625  1.362637  1.608108  1.36
#
# floor         22    23     24    25        26   27   28   29   32   33
# balcony  1.52381  1.35  1.775  1.36  1.722222  1.6  1.0  2.0  0.0  2.0

# %%
sns.set(rc={'figure.figsize':(14,8)})

# %%
# посмотрим на диаграмме на каких этажах нет балконов
sns.countplot(data[data['balcony'] == 0]['floor']).set_title('Распределение этажей, на которых находятся объекты недвижимости без балконов');

# %%
# посмотрим на диаграмме на каких этажах 1 балкон
sns.countplot(data[data['balcony'] == 1]['floor']).set_title('Распределение этажей, на которых находятся объекты недвижимости с 1 балконом');

# %%
# посмотрим на диаграмме как распределены этажи в объектах с пропущенными значениями балконов
sns.countplot(data[data['balcony'].isna()]['floor']).set_title('Распределение этажей, на которых находятся объекты недвижимости с пропусками в признаке балконов');

# %% [markdown]
# Данные достаточно неоднозначны - логично, что балконов достаточно часто нет на 1 этаже, хотя встречаются (и немало) объекты с 1 балконом на 1 этаже, да и среднее значение балконов на 1 этаже не стремится к 0 (0.71).
#
# Можно предположить, что продавцы квартир без балконов предпочитают не указывать информацию об их отсутствии, поэтому заполним пропуски нулем, введя признак, что в данных был пропуск.
#
# Изменим тип данных на int, т.к. число балконов - целое.

# %%
data['balcony_nan_flag'] = 0
data.loc[data['balcony'].isna(), 'balcony_nan_flag'] = 1
data.loc[data['balcony'].isna(), 'balcony'] = 0

# %%
data['balcony'] = data['balcony'].astype('int')

# %%
# смотрим статистику по признаку
feature_stat(data, 'balcony')
# Out:
# Признак balcony
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 6
# Минимальное значение: 0.0
# Максимальное значение: 5.0
# Медиана: 0.0
# Среднее: 0.5910797923963036
# Мода: 0
# Тип данных: int64
# ____________________________________________________________________________________________________

# %% [markdown]
# Работа с признаком завершена.

# %% [markdown]
# ### Признак locality_name

# %%
# смотрим статистику по признаку
feature_stat(data, 'locality_name', print_nan=True)
# Out:
# Признак locality_name
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 49 (0.2%)
# Кол-во уникальных значений: 364
# Мода: Санкт-Петербург
# Тип данных: object
# ____________________________________________________________________________________________________
# Пять случайных объектов с пропусками
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 17764             9   8400000.0        94.0  2016-01-24T00:00:00      3
# 2603             20   3351765.0        42.7  2015-09-20T00:00:00      1
# 12936             6   6800000.0        73.0  2015-11-01T00:00:00      3
# 22717             9   3000000.0        35.0  2018-01-02T00:00:00      1
# 16561             3   2450000.0        30.0  2016-06-02T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 17764            2.65            23         52.0      5         False   False
# ...

# %% [markdown]
# Пропусков в признаке достаточно мало (0.2%) и при этом достаточно много уникальных значений.
#
# Посмотрим на данные подробнее.

# %%
data['locality_name'].value_counts()
# Out:
# Санкт-Петербург                   15721
# посёлок Мурино                      522
# посёлок Шушары                      440
# Всеволожск                          398
# Пушкин                              369
#                                   ...
# поселок Пчевжа                        1
# поселок городского типа Рябово        1
# поселок Каложицы                      1
# садовое товарищество Рахья            1
# поселок Гладкое                       1
# Name: locality_name, Length: 364, dtype: int64

# %% [markdown]
# Более 66% объектов расположено в Санкт-Петербурге.
#
# Нужно определить, как действовать с пропусками.
#
# С одной стороны, локация достаточно важна для последующего анализа, однако с учетом малого числа пропусков, маловероятно, что они смогут критично повлиять на его результат.
#
# Изучим подробнее данные, в которых есть пропуски.

# %%
data[data['locality_name'].isna()]['last_price'].median()
# Out:
# 5130593.0

# %%
data.groupby('locality_name')['last_price'].median().sort_values(ascending=False).head(10)
# Out:
# locality_name
# деревня Хязельки           11000000.0
# деревня Бор                10397600.0
# посёлок Александровская     8725000.0
# посёлок Репино              8083708.0
# Санкт-Петербург             5500000.0
# Сестрорецк                  5450000.0
# Пушкин                      5180000.0
# посёлок Лисий Нос           5027500.0
# деревня Глинка              4750000.0
# Зеленогорск                 4750000.0
# Name: last_price, dtype: float64

# %% [markdown]
# По медиане цены пропущенные значения достаточно похожи на Санкт-Петербург.

# %%
data[data['locality_name'].isna()]['cityCenters_nearest'].median()
# Out:
# 8943.0

# %%
data.groupby('locality_name')['cityCenters_nearest'].median().sort_values().head(10)
# Out:
# locality_name
# Санкт-Петербург            12244.5
# посёлок Парголово          19311.0
# поселок Мурино             21888.0
# посёлок Стрельна           23506.0
# посёлок Шушары             24212.0
# посёлок Левашово           25727.0
# посёлок Песочный           26099.5
# посёлок Петро-Славянка     27165.0
# посёлок Лисий Нос          27297.0
# посёлок Александровская    27468.0
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# По близости к центру, пропущенные значения также достаточно похожи на Санкт-Петербург.
#
# Учитывая, что Санкт-Петербург имеет самую высокую долю среди объектов (более 66%), заменим пропущенные значения на него.

# %%
# заполним пропуски, округлив до второго знака после запятой
data['locality_name_nan_flag'] = 0
data.loc[data['locality_name'].isna(), 'locality_name_nan_flag'] = 1
data.loc[data['locality_name'].isna(), 'locality_name'] = 'Санкт-Петербург'

# %%
# смотрим статистику по признаку
feature_stat(data, 'locality_name', print_nan=True)
# Out:
# Признак locality_name
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 364
# Мода: Санкт-Петербург
# Тип данных: object
# ____________________________________________________________________________________________________
# Пять случайных объектов с пропусками
# При выполнении произошла ошибка. Возможно, в данных нет пропусков
# ____________________________________________________________________________________________________

# %% [markdown]
# Пропуски удалены, тип данных корректен, работа с признаком завершена.

# %% [markdown]
# ###  Остальные признаки

# %% [markdown]
# Данные признаки, независимо от числа пропусков в них, характеризуются тем, что данные нам получить неоткуда (можно было бы попробовать как-то сопоставить расстояния до центра с другими, но это не совсем корректно и достаточно трудоемко). При этом, характер этих пропусков скорее технический - при указании адреса продажи, соответствующая информация должна быть получена от информационных систем. Поэтому для корректировки этих данных в реальном проекте корректнее всего обратиться к специалистам, отвечающим за подготовку данных или их выгрузку.
#
# Заполним пропуски нулями, введя признак-флаг о том, что они были. Но сначала приведем название cityCenters_nearest к snake_case.

# %%
# приведем название признака 'cityCenters_nearest' к snake_case
data.rename(columns={'cityCenters_nearest': 'city_centers_nearest'}, inplace=True)

# %%
features_to_fill = ['airports_nearest', 'city_centers_nearest', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'days_exposition']

# %%
for feature in features_to_fill:
    data[feature+'_nan_flag'] = 0
    data.loc[data[feature].isna(), feature+'_nan_flag'] = 1
data[features_to_fill] = data[features_to_fill].fillna(0)

# %%
# посмотрим еще раз на данные
data.sample(7)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 7548              4  19500000.0       84.58  2018-11-19T00:00:00      2
# 18603            17   4300000.0       61.00  2017-07-12T00:00:00      3
# 6433              6   3700000.0       50.20  2017-11-02T00:00:00      1
# 20798             6   4550000.0       39.00  2019-03-15T00:00:00      1
# 16374             4  19173000.0       91.30  2018-01-13T00:00:00      3
# 4393              7   4925000.0       38.80  2016-08-17T00:00:00      1
# 7566              7  15890000.0      178.00  2018-09-17T00:00:00      6
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 7548             2.65             9        37.10      2         False   False
# 18603            2.65             5        43.60      2         False   False
# 6433             2.55            10        19.00     10         False   False
# 20798            2.70            16        21.00      7         False   False
# ...

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# Нам необходимо исправить типы данных у следующих признаков:
# - last_price: на int (значения достаточно велики, вещественных чисел нет).
# - first_day_exposition: на datetime.
# - airports_nearest: на int (значения достаточно велики, вещественных чисел нет).
# - city_centers_nearest: на int (значения достаточно велики, вещественных чисел нет).
# - parks_around3000, ponds_around3000: на int (кол-во парков и водоемов - целое число).
# - parks_nearest, ponds_nearest: на int (значения достаточно велики, вещественных чисел нет).
# - days_exposition: на int (кол-во дней - целое число).

# %%
# все признаки, кроме first_day_exposition
features_to_change_type = ['last_price', 'airports_nearest', 'city_centers_nearest', 'parks_around3000',
                           'ponds_around3000', 'parks_nearest', 'ponds_nearest', 'days_exposition']

# %%
data[features_to_change_type] = data[features_to_change_type].astype('int')

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], 
                                              format="%Y-%m-%dT%H:%M:%S")

# %% [markdown]
# ### Результаты предобработки данных

# %% [markdown]
# Мы провели обработку следующих признаков:
# 1. ceiling_height: в признаке было 38.8% пропусков, мы заполнили их медианой, однако отметили, что это приведет к существенному перекосу в сторону медианного значения (посмотрим на этот признак внимательнее в разделе исследовательского анализа).
# 2. floors_total: в признаке было не очень много пропусков (0.4%), мы заполнили их большим из двух значений (этаж квартиры или медианное значения этажа по всей выборке), в данных создали признак-флаг, чтобы отличать значения, которые были заполнены.
# 3. living_area: в признаке было 8% пропусков, мы обнаружили высокую корреляцию этого признака с total_area (0.94), поэтому заполнили пропуски с использованием отношения медианных значений общей площади к жилой по всей выборке, в данных создали признак-флаг, чтобы отличать значения, которые были заполнены.
# 4. is_apartment: в данных было более 88% пропусков, причем для заполненных данных доля апартаментов составляет менее 1%. Мы заполнили пропуски значением False, в данных создали признак-флаг, чтобы отличать значения, которые были заполнены.
# 5. kitchen_area: в данных было 9.6% пропусков, как и с жилой площадью мы использовали для заполнения отношение медианных значений общей площади к кухонной по всей выборке, однако учли, что в некоторых случаях при таком заполнении сумма жилой и кухонной площади может стать больше общей. Для такой ситуации признак рассчитывался как разность общей площади и жилой. В данных также создали признак-флаг, чтобы отличать значения, которые были заполнены.
# 6. balcony: в данных было 48.6% пропусков, в ходе небольшого исследования мы не смогли установить оптимальный метод их заполнения, поэтому заполнили пропуски значением -1, чтобы их можно было отличать на графиках.
# 7. locality_name: в данных было мало пропусков (0.2%), с учетом высокой доли Санкт-Петербурга в общей выборке и схожести средних цен на квартиры в пропущенных значениях и в Петербурге, мы заполнили пропуски значением "Санкт-Петербург".
# 8. airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition: c учетом предположительно технического характера данных пропусков (некорректно выгруженная информация из БД, ошибки при парсинге?) и отсутствием возможности заполнить их корректными значениями исходя из логики, вместо пропусков мы поставили значения -1.
#
# Для части признаков также был изменен тип данных:
# 1. last_price: на int (значения достаточно велики, вещественных чисел нет).
# 2. first_day_exposition: на datetime.
# 3. airports_nearest: на int (значения достаточно велики, вещественных чисел нет).
# 4. city_centers_nearest: на int (значения достаточно велики, вещественных чисел нет).
# 5. parks_around3000, ponds_around3000: на int (кол-во парков и водоемов - целое число).
# 6. parks_nearest, ponds_nearest: на int (значения достаточно велики, вещественных чисел нет).
# 7. days_exposition: на int (кол-во дней - целое число).
# 8. floors_total: на int (кол-во этажей - целое число).
#
# Вся предварительная обработка (за исключеним аномалий) завершена.
#
# Проверим общую информацию о данных.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 36 columns):
# total_images                     23699 non-null int64
# last_price                       23699 non-null int64
# total_area                       23699 non-null float64
# first_day_exposition             23699 non-null datetime64[ns]
# rooms                            23699 non-null int64
# ceiling_height                   23699 non-null float64
# floors_total                     23699 non-null int64
# living_area                      23699 non-null float64
# floor                            23699 non-null int64
# is_apartment                     23699 non-null bool
# studio                           23699 non-null bool
# open_plan                        23699 non-null bool
# kitchen_area                     23699 non-null float64
# balcony                          23699 non-null int64
# locality_name                    23699 non-null object
# ...

# %% [markdown]
# Типы данных корректны, пропусков нет. Переходим к следующему разделу.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Нам нужно добавить следующие признаки:
# - цена квадратного метра;
# - день недели, месяц и год публикации объявления;
# - этаж квартиры; варианты — первый, последний, другой;
# - соотношение жилой и общей площади;
# - отношение площади кухни к общей.

# %%
# цена квадратного метра
data['meter_price'] = data['last_price'] / data['total_area']

# %%
# день недели, месяц и год публикации объявления
# для дня недели используем day_name, а не week_day, чтобы было нагляднее на графиках
data['adv_day_of_week'] = data['first_day_exposition'].dt.day_name()
data['adv_month'] = data['first_day_exposition'].dt.month
data['adv_year'] = data['first_day_exposition'].dt.year

# %%
# этаж квартиры; варианты — первый, последний, другой
def fill_floor(row):
    if row['floor'] == row['floors_total']:
        return 'последний'
    elif row['floor'] == 1:
        return 'первый'
    else:
        return 'другой'

# %%
data['floor_type'] = data.apply(fill_floor, axis=1)

# %%
# соотношение жилой и общей площади
data['living_to_total_area_ratio'] = data['living_area'] / data['total_area']

# %%
# отношение площади кухни к общей
data['kitchen_to_total_area_ratio'] = data['kitchen_area'] / data['total_area']

# %% [markdown]
# Проверяем

# %%
data.sample(7)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5903             11     4600000        53.0           2016-04-04      2
# 645              18     4775000        39.6           2017-07-15      1
# 14569            16     8750000        65.0           2019-03-21      2
# 22123            14     5680000        41.7           2018-09-07      1
# 18786             5     3700000        40.0           2017-02-16      1
# 1378             16    15990000        58.5           2016-11-01      2
# 5658              8     3120000        44.4           2017-07-07      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 5903             2.60            15        25.81      9         False   False
# 645              2.65            17        20.00     17         False   False
# 14569            2.65            17        32.00      3         False   False
# 22123            2.75            25        19.30     12         False   False
# ...

# %% [markdown]
# Признаки созданы корректно. Переходим дальше.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучение площади, цены, числа комнат, высоты потолков.

# %% [markdown]
# #### Площадь

# %%
# смотрим статистику по признаку
feature_stat(data, 'total_area', print_high=True, print_low=True, need_hist=True, hist_bins=25)
# Out:
# Признак total_area
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 2182
# Минимальное значение: 12.0
# Максимальное значение: 900.0
# Медиана: 52.0
# Среднее: 60.34865099793241
# Мода: 45.0
# Тип данных: float64
# ____________________________________________________________________________________________________
# Гистограмма
# ____________________________________________________________________________________________________
# Пять самых низких значений
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 19904             4     2400000        12.0           2017-07-19      1
# 17961             3     1400000        13.0           2017-12-03      1
# 19546             3     1850000        13.0           2019-03-11      1
# 19807             0     3800000        13.0           2018-07-04      1
# ...

# %% [markdown]
# Видим малое число объектов большой площади, из-за чего гистограмма не очень наглядна.
#
# Следует отметить некоторое количество совсем маленьких объектов - 12-13 метров (скорее всего это объекты с долевым владением - об этом свидетельствуют и малые значения жилой и кухонной площади для данных объектов).
#
# Объекты с большой площадью (пять самых дорогих) на первый взгляд также кажутся достаточно корректными с точки зрения данных (последний этаж, высокая цена), однако для анализа от совсем больших и совсем малых значений, скорее всего, придется избавиться.
#
# Посмотрим на диаграмму размаха, чтобы оценить потенциальные выбросы.

# %%
# функция, определяющая границы отсечения аномалий
def get_anomaly_values(data, feature):
    feature_stats = data[feature].describe()
    q1 = feature_stats['25%']
    q3 = feature_stats['75%']
    interquartile = q3 - q1
    print(f'Границы отсечения аномалий: {max(0, q1 - 1.5 * interquartile)}, {q3 + 1.5 * interquartile}')

# %%
sns.boxplot(data['total_area'], orient='h');

# %%
get_anomaly_values(data, 'total_area')
# Out:
# Границы отсечения аномалий: 0, 114.75000000000001

# %% [markdown]
# В соответствии с диаграммой размаха, аномальными можно считать площади квартир >= 115 метров. Построим гистограмму для этих данных.

# %%
my_hist(data[data['total_area'] < 115], 'total_area')

# %% [markdown]
# Большинство объектов расположено в границах от 30 до 110 метров. Среднее немного сдвинуто вправо, что связано с большим "хвостом" справа.
#
# Нам также необходимо будет избавиться от аномалий в совсем малых значениях, поскольку таких данных относительно мало и проводить анализ, захватывая комнаты в коммунальных квартирах, так же, как и элитную недвижимость, не совсем корректно.
#
# Посмотрим на 0.5, 1, 2.5 перцентили.

# %%
print(f'{[f"{x:.1%}: {data.total_area.quantile(x)}" for x in [0.005, 0.01, 0.025]]}')
# Out:
# ['0.5%: 23.5', '1.0%: 25.198999999999998', '2.5%: 29.0']

# %% [markdown]
# Видим, что 0.5 процента самых маленьких объектов по размеру 23.5 метра и менее. Это значение выглядит достаточно корретным для того, чтобы отсечь из выборки отдельные комнаты.
#
# Таким образом, для корректировки аномалий в данном признаке в дальнейшем будем рассматривать квартиры с площадью от 23.5 до 115 метров. Для будущего сравнения с квартирами в центре выведем статистическую информацию по данным с выбранным фильтром.

# %%
feature_stat(data.query('23.5 < total_area < 115'), 'total_area')
# Out:
# Признак total_area
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 1601
# Минимальное значение: 23.55
# Максимальное значение: 114.8
# Медиана: 50.4
# Среднее: 54.55313848357354
# Мода: 45.0
# Тип данных: float64
# ____________________________________________________________________________________________________

# %% [markdown]
# #### Цена

# %%
# смотрим статистику по признаку
feature_stat(data, 'last_price', print_high=True, print_low=True, need_hist=True, hist_bins=70)
# Out:
# Признак last_price
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 2978
# Минимальное значение: 12190.0
# Максимальное значение: 763000000.0
# Медиана: 4650000.0
# Среднее: 6541548.771551542
# Мода: 4500000
# Тип данных: int64
# ____________________________________________________________________________________________________
# Гистограмма
# ____________________________________________________________________________________________________
# Пять самых низких значений
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 8793              7       12190       109.0           2019-03-20      2
# 17456             7      430000        30.4           2019-04-22      1
# 14911             5      430000        54.0           2018-06-26      2
# 16274            18      440000        40.0           2018-07-10      1
# ...

# %% [markdown]
# Есть некоторые выбросы в маленьких значениях (самое маленькое значение цены - 12190, предположительно забыты 3 нуля - об этом нам говорит и слишком малая цена за метр у данного объекта, остальные маленькие значения похожи на корректные, с учетом локации и остальных данных), и в самых больших значениях (самые дорогие объекты более 400 млн.руб.). Вполне вероятно, что большие значения достаточно корректны, учитывая характеристики данных объектов (элитная недвижимость, последние этажи - лофты?, большая площадь, локация - Санкт-Петербург, близость парков и водоемов).
#
# Несмотря на видимую правильность больших значений, для дальнейшего построения корректной модели объекты со слишком высокими значениями было бы корректнее отбросить, т.к. ценообразование элитной недвижимости разумнее проводить в ручном режиме или хотя бы имея достаточно данных (чего в нашем случае нет).
#
# Определим критерий отсечения дорогой недвижимости по диаграмме размаха.

# %%
sns.boxplot(data['last_price'], orient='h');

# %%
get_anomaly_values(data, 'last_price')
# Out:
# Границы отсечения аномалий: 0, 11900000.0

# %% [markdown]
# Разброс в ценах настолько большой, что визуально оценить границы допустимых представляется невозможным.
#
# Критерии построения диаграммы определяет границу выбросов в 11900000, построим гистограмму с таким фильтром.

# %%
feature_stat(data[data['last_price'] < 11.9e6], 'last_price', need_hist=True)
# Out:
# Признак last_price
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 2221
# Минимальное значение: 12190.0
# Максимальное значение: 11894400.0
# Медиана: 4400000.0
# Среднее: 4839969.752611147
# Мода: 4500000
# Тип данных: int64
# ____________________________________________________________________________________________________
# Гистограмма
# ____________________________________________________________________________________________________

# %% [markdown]
# Распределение стало походить на нормальное с небольшим хвостом вправо. При этом, объектов дешевле 2 млн. также немало (порядка 2000). Скорее всего это комнаты (малая площадь) и объекты за пределами Санкт-Петербурга.

# %%
data[data['last_price'] < 2e6].groupby('locality_name')['locality_name'].count().sort_values(ascending=False)
# Out:
# locality_name
# Сланцы                             110
# Кириши                              87
# Волхов                              78
# Приозерск                           37
# Выборг                              36
#                                   ...
# поселок Почап                        1
# поселок Поляны                       1
# деревня Парицы                       1
# деревня Пельгора                     1
# посёлок Платформа 69-й километр      1
# Name: locality_name, Length: 278, dtype: int64

# %% [markdown]
# Большинство дешевых объектов действительно за пределами Петербурга. Фильтровать низкие значения по критерию цены мы не будем, чтобы не убрать из выборки слишком много населенных пунктов с дешевыми объектами недвижимости.
#
# На данном этапе предположим необходимость фильтрации объектов с ценой более 11.9 млн.

# %% [markdown]
# #### Число комнат

# %%
# смотрим статистику по признаку
feature_stat(data, 'rooms', print_high=True, print_low=True, need_hist=True, hist_bins=20)
# Out:
# Признак rooms
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 17
# Минимальное значение: 0.0
# Максимальное значение: 19.0
# Медиана: 2.0
# Среднее: 2.070635891809781
# Мода: 1
# Тип данных: int64
# ____________________________________________________________________________________________________
# Гистограмма
# ____________________________________________________________________________________________________
# Пять самых низких значений
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 9412              5     2100000        16.0           2017-12-10      0
# 8886             10     2450000        15.5           2018-08-22      0
# 18132             6     4800000        32.5           2019-04-09      0
# 20002             8     2700000        28.0           2017-11-10      0
# ...

# %% [markdown]
# Снова "хвост" справа, от достаточно дорогих объектов (>25 млн.) с кол-вом комнат >14.
#
# Интересно, что у объектов с количеством комнат, равным 0, иногда стоит флаг studio, а иногда open_plan, но не оба вместе.
#
# Оценим выбросы по диаграмме размаха.

# %%
sns.boxplot(data['rooms'], orient='h');

# %%
get_anomaly_values(data, 'rooms')
# Out:
# Границы отсечения аномалий: 0, 6.0

# %% [markdown]
# Выведем статистические данные и построим гистограмму для кол-ва комнат <=6.

# %%
feature_stat(data.query('rooms <= 6'), 'rooms')
# Out:
# Признак rooms
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 7
# Минимальное значение: 0.0
# Максимальное значение: 6.0
# Медиана: 2.0
# Среднее: 2.0479054597822866
# Мода: 1
# Тип данных: int64
# ____________________________________________________________________________________________________

# %%
my_hist(data[data['rooms'] <= 6], 'rooms', bins=7)

# %% [markdown]
# Видно, что значений 0 также достаточно мало, однако исключать объекты с 0 комнат не вполне корректно, т.к. вместе с ними у нас может уйти целый "пласт" объектов-студий.
#
# Таким образом, критерий обработки аномалий для данного признака - оставлять объекты с 6 комнатами и меньше.

# %% [markdown]
# #### Высота потолков

# %% [markdown]
# В этом признаке мы заполняли пропуски, поэтому сравним все данные и данные, в которых пропусков не было.

# %%
# смотрим статистику по признаку (все данные)
feature_stat(data, 'ceiling_height', print_high=True, print_low=True, need_hist=True, hist_bins=20)
# Out:
# Признак ceiling_height
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 183
# Минимальное значение: 1.0
# Максимальное значение: 100.0
# Медиана: 2.65
# Среднее: 2.724358411747331
# Мода: 2.65
# Тип данных: float64
# ____________________________________________________________________________________________________
# Гистограмма
# ____________________________________________________________________________________________________
# Пять самых низких значений
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 22590            16     6000000        55.0           2018-10-31      2
# 5712              5     1500000        42.8           2017-08-14      2
# 16934             5     4100000        40.0           2017-10-17      1
# 20520             9     3600000        38.0           2018-07-05      1
# ...

# %% [markdown]
# Снова "хвост" справа, при этом как в самых маленьких, так и в самых больших значениях присутствуют какие-то совсем некорретные значения (потолки 1, 1.2, 100 метров). Такие объекты придется исключить.
#
# Посмотрим на гистограмму без самых больших значений (потолки не выше 5 метров).

# %%
my_hist(data[data['ceiling_height'] < 5], 'ceiling_height', bins=20)

# %% [markdown]
# Большинство данных расположено в пределах 2.5-3 метров, c большим столбцом около медианы (поскольку мы использовали ее для заполнения пропусков).
#
# Посмотрим на гистограмму данных, в которых не было пропусков.

# %%
my_hist(data[(data['ceiling_height'] < 5) & (data['ceiling_height_nan_flag'] != 1)], 'ceiling_height', bins=20)

# %% [markdown]
# Существенно меньший перекос в сторону медианного значения. Для построения дальнейших выводов корректнее использовать этот ограниченный, но более точный набор данных.
#
# Посмотрим корректные границы отсечения аномальных значений по диаграмме размаха.

# %%
sns.boxplot(data[data['ceiling_height_nan_flag'] != 1]['ceiling_height'], orient='h');

# %%
get_anomaly_values(data[data['ceiling_height_nan_flag'] != 1], 'ceiling_height')
# Out:
# Границы отсечения аномалий: 2.1000000000000005, 3.2199999999999998

# %% [markdown]
# Предлагаемая граница отсечения "сверху" - 3.2 метра. "Снизу", с точки зрения логики, можно было бы поднять границу до 2.4 метра - объектов недвижимости с потолками ниже этого значения, скорее всего, не существует или они будут не очень репрезентативны. Таким образом, наш критерий отсечения (потолки от 2.4 до 3.2 метров).
#
# Выведем статистику по данному критерию для последующего сравнения с квартирами в центре.

# %%
feature_stat(data.query('ceiling_height_nan_flag != 1 and 2.4 <= ceiling_height <= 3.2'), 'ceiling_height', need_hist=True, hist_bins=15)
# Out:
# Признак ceiling_height
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 76
# Минимальное значение: 2.4
# Максимальное значение: 3.2
# Медиана: 2.64
# Среднее: 2.680101712278648
# Мода: 2.5
# Тип данных: float64
# ____________________________________________________________________________________________________
# Гистограмма
# ____________________________________________________________________________________________________

# %% [markdown]
# ### Изучаем время продажи квартиры.

# %% [markdown]
# В данном признаке мы заполняли пропуски значением 0, поэтому имеет смысл смотреть на данные, отфильтровав эти значения.

# %%
# смотрим статистику по признаку (все данные)
feature_stat(data[data['days_exposition_nan_flag'] != 1], 'days_exposition', 
             print_high=True, 
             print_low=True, 
             need_hist=True,
             hist_bins=20)
# Out:
# Признак days_exposition
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 1141
# Минимальное значение: 1.0
# Максимальное значение: 1580.0
# Медиана: 95.0
# Среднее: 180.88863436982163
# Мода: 45
# Тип данных: int64
# ____________________________________________________________________________________________________
# Гистограмма
# ____________________________________________________________________________________________________
# Пять самых низких значений
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1632             19     4000000        49.9           2019-05-01      2
# 16053             4     4070000        45.1           2019-04-30      2
# 13061            20     6100000        51.4           2019-04-29      2
# 16212             0     7806000        25.0           2019-04-30      1
# ...

# %% [markdown]
# Видим распределение Пуассона с длинным "хвостом" справа: некоторые объекты были выставлены на продажу более 1500 дней. Самые "быстрые" продажи занимали несколько дней (1-2) - возможно, объявления снимались без продажи (в описании указано лишь, что в данном признаке содержится время до снятия объявления - необязательно, что оно закончилось продажей).
#
# Медианный срок продажи составляет порядка 3 месяцев (95 дней), средний срок продажи - 180 дней (почти полгода).
#
# Оценим, какие продажи считать быстрыми, а какие долгими. Посмотрим на 1, 5, 10 (90, 95, 99) процентили соответственно.

# %%
days_exposition_percentiles = [0.005, 0.01, 0.025, 0.05, 0.1, 0.9, 0.95, 0.975, 0.99]
for percentile in days_exposition_percentiles:
    print(f'Продажи {percentile:.1%} объектов не дольше {data[data["days_exposition_nan_flag"] != 1]["days_exposition"].quantile(percentile):.0f} дней')
# Out:
# Продажи 0.5% объектов не дольше 3 дней
# Продажи 1.0% объектов не дольше 4 дней
# Продажи 2.5% объектов не дольше 6 дней
# Продажи 5.0% объектов не дольше 9 дней
# Продажи 10.0% объектов не дольше 17 дней
# Продажи 90.0% объектов не дольше 460 дней
# Продажи 95.0% объектов не дольше 647 дней
# Продажи 97.5% объектов не дольше 846 дней
# Продажи 99.0% объектов не дольше 1069 дней

# %% [markdown]
# Видим, что 1% объектов продается за 4 дня и быстрее, а 1% - за 1069 дней и дольше. Эти значения выглядят слишком быстрыми и, соответственно, долгими для включения их в анализ.
#
# Слишком маленькие значения могут свидетельствовать о том, что человек передумал продавать квартиру или у него были какие-либо причины продать ее слишком быстро (юридические проблемы, срочный переезд, долги), слишком долгие продажи, свидетельствуют о том, что с другими признаками таких объектов что-то не так (слишком дорогие объекты, неудачная локация, обременения), либо объявление просто забыли снять. В обоих случаях ориентироваться на слишком быстрые и слишком долгие продажи для корректного анализа не кажется правильным.
#
# В дальнейшем исключим продажи объектов из 1% перцентиля, верхнюю границу выбросов определим по диаграмме размаха.

# %%
sns.boxplot(data[data['days_exposition'] != 0]['days_exposition'], orient='h');

# %%
get_anomaly_values(data[data['days_exposition'] != 0], 'days_exposition')
# Out:
# Границы отсечения аномалий: 0, 512.5

# %% [markdown]
# В соответствии с диаграммой размаха видим потенциальные выбросы на отметке более 512 дней.
# Таким образом, потенциальная зона отсечения для аномалий: менее 4 дней и более 512 дней.

# %% [markdown]
# Посмотрим на гистограмму этих данных.

# %%
filter = ((data['days_exposition'] > 4) & 
          (data['days_exposition'] < 513))

# %%
feature_stat(data[filter], 'days_exposition', need_hist=True, hist_bins=20)
# Out:
# Признак days_exposition
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 508
# Минимальное значение: 5.0
# Максимальное значение: 512.0
# Медиана: 88.0
# Среднее: 131.040840581276
# Мода: 45
# Тип данных: int64
# ____________________________________________________________________________________________________
# Гистограмма
# ____________________________________________________________________________________________________

# %% [markdown]
# С примененным фильтром гистограмма визуально выглядит корректнее. Медианное время продажи таких объектов практически не изменилось (3 месяца или 88 дней), а среднее сместилось ближе к 4 месяцам (131 день).

# %% [markdown]
# ### Работаем с аномалиями

# %% [markdown]
# Мы определили критерии, по которым уберем аномалии в признаках total_area, last_price, rooms, ceiling_height, days_exposition.
#
# Устраним в первую очередь их, но сначала исправим цену у объекта недвижимости с самой низкой ценой.

# %%
data.loc[8793, 'last_price'] *= 1000
data.loc[8793, 'meter_price'] *= 1000

# %%
filter_data = data.query("23.5 < total_area < 115 and last_price < 11.9e6 and rooms <= 6 and 2.4 <= ceiling_height <= 3.2 and (4 < days_exposition < 513 or days_exposition == 0)")

# %%
# посмотрим какой процент данных мы потеряли после фильтрации
filter_data.shape[0] / data.shape[0]
# Out:
# 0.8121439723195072

# %% [markdown]
# Всего отфильтровано около 19% данных.

# %% [markdown]
# Корректировку аномалий в остальных признаках, за исключением удалённости от центра, можно не проводить, т.к. они не используются в дальнейшем анализе.
#
# Посмотрим на признак city_centers_nearest.

# %%
feature_stat(filter_data[filter_data.city_centers_nearest != -1], 'city_centers_nearest', need_hist=True, hist_bins=29)
# Out:
# Признак city_centers_nearest
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 6502
# Минимальное значение: 0.0
# Максимальное значение: 65952.0
# Медиана: 11907.0
# Среднее: 11350.44412116174
# Мода: 0
# Тип данных: int64
# ____________________________________________________________________________________________________
# Гистограмма
# ____________________________________________________________________________________________________

# %% [markdown]
# Немного смущают максимальные значения порядка 66 километров, однако если расстояние считается от центра Петербурга до других населенных пунктов, то может быть с данными все в порядке.
#
# Посмотрим на самое большое значение глазами.

# %%
filter_data.loc[[filter_data.city_centers_nearest.idxmax()]]
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 5340            19     3600000        50.6           2019-03-19      2
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 5340             2.5             5         29.9      4         False   False
#
#       open_plan  kitchen_area  balcony       locality_name  airports_nearest  \
# 5340      False           7.0        1  посёлок Молодёжное             84853
#
#       city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 5340                 65952                 0              0                 0
#
#       ponds_nearest  days_exposition  ceiling_height_nan_flag  \
# 5340              0                0                        0
#
#       floors_total_nan_flag  living_area_nan_flag  is_apartment_nan_flag  \
# 5340                      0                     0                      1
#
# ...

# %% [markdown]
# Поселок Молодежное - судя по картам, он действительно расположен примерно в 60 километрах от Петербурга.
#
# Данные в целом корректны, поэтому чтобы не потерять данные по достаточно удаленным от Петербурга населенным пунктам, аномалии в данном признаке исключать не будем.

# %% [markdown]
# В целом, мы обнаружили достаточное количество аномалий в данных:
# 1. Объекты с очень малой площадью (около 10 метров): предположительно комнаты в коммунальных квартирах.
# 2. Объекты с очень большой площадью (более 500 метров): предположительно элитная недвижимость или частные дома (которые могли попасть в данные ошибочно, т.к. они должны были содержать только информацию о квартирах).
# 3. Слишком дорогие объекты (более 300 млн.): предположительно все та же элитная недвижимость или частные дома.
# 4. Слишком дешевые объекты (около 400 тыс.): старый фонд или неудачные локации.  Эти данные мы не фильтровали, чтобы не исключить информацию о целых населенных пунктах.
# 5. Объекты с очень большим числом комнат (вплоть до 19): большие элитные или бывшие коммунальные квартиры, а также частные дома.
# 6. Объекты с некорректной высотой потолков (1, 1.2, 100 метров).
# 7. Объекты с некорректным временем продажи (менее 5 дней и более 512 дней).
#
# Все критичные для проведения дальнейшего исследования аномалии были отфильтрованы.

# %% [markdown]
# ### Факторы, влияющие на стоимость квартиры

# %% [markdown]
# #### Зависимость цены от площади

# %% [markdown]
# Попробуем посмотреть на коэффициент корреляции между этими параметрами.

# %%
filter_data[['total_area', 'last_price']].corr()
# Out:
#             total_area  last_price
# total_area    1.000000    0.684137
# last_price    0.684137    1.000000

# %% [markdown]
# Некоторая прямая зависимость цены от площади определенно есть (коэффициент корреляции 0.684).
#
# Построим регрессионный график.

# %%
sns.regplot(x='total_area', y='last_price', data=filter_data, scatter_kws={'alpha':0.1});

# %% [markdown]
# Мы видим определенную линейную зависимость цены от площади объекта, однако можно сказать, что на цену влияют и другие факторы (особенно для квартир большой площади, где разброс достаточно велик). Посмотрим зависимость цены от площади для Санкт-Петербурга.

# %%
sns.regplot(x='total_area', 
            y='last_price', 
            data=filter_data[filter_data.locality_name=='Санкт-Петербург'], 
            scatter_kws={'alpha':0.1});

# %% [markdown]
# Данные расположены значительно более кучно с некоторым увеличением разброса по мере увеличения площади квартиры.

# %%
filter_data[filter_data.locality_name == 'Санкт-Петербург'][['total_area', 'last_price']].corr()
# Out:
#             total_area  last_price
# total_area    1.000000    0.791217
# last_price    0.791217    1.000000

# %% [markdown]
# Коэффициент корреляции при ограничении территории также выше (0.791 для Санкт-Петербурга), что свидетельствует о важности дополнительных признаков при анализе стоимости квартиры (из-за существенного разброса данных в зависимости от них).

# %% [markdown]
# #### Зависимость цены от числа  комнат

# %% [markdown]
# Смотрим на коэффициент корреляции

# %%
filter_data[['rooms', 'last_price']].corr()
# Out:
#                rooms  last_price
# rooms       1.000000    0.419651
# last_price  0.419651    1.000000

# %% [markdown]
# Определенная корреляция есть, но она не так велика. Посмотрим на стобчатую диаграмму.

# %%
sns.catplot(x='rooms', y='last_price', kind="bar", data=filter_data);

# %% [markdown]
# Видим некоторое увеличение средней стоимости квартир по мере увеличения числа комнат, однако на объектах с 5 и 6 комнатами значительно начинает увеличиваться разброс, что свидетельствует о важности дополнительных параметров для данного жилья.

# %% [markdown]
# В целом, можно отметить, что количество комнат в меньшей степени влияет на стоимость квартиры, чем ее площадь. Для многокомнатных объектов (4 комнаты и больше) большее влияние начинают оказывать дополнительные факторы.

# %% [markdown]
# #### Зависимость цены от удаленности от центра

# %% [markdown]
# Смотрим на коэффициент корреляции (не учитывая заполненные нами ранее данные)

# %%
filter_data[filter_data.city_centers_nearest_nan_flag != 1][['city_centers_nearest', 'last_price']].corr()
# Out:
#                       city_centers_nearest  last_price
# city_centers_nearest               1.00000    -0.32712
# last_price                        -0.32712     1.00000

# %% [markdown]
# Видна относительно небольшая обратная зависимость между данными признаками: по мере удаленности от центра стоимость квартир падает (что достаточно логично).
#
# Построим регрессионный график.

# %%
sns.regplot(x='city_centers_nearest', 
            y='last_price', 
            data=filter_data[filter_data.city_centers_nearest_nan_flag != 1], 
            scatter_kws={'alpha':0.1});

# %% [markdown]
# Некоторая зависимость прослеживается, однако в данных также присутствует существенный разброс значений. Заметно, что для расстояний от центра более 20 км (скорее всего, это объекты не в Санкт-Петербурге) предсказательная сила регрессии начинает снижаться (все больше объектов удаляются от линии регрессии).
#
# Посмотрим на график только для Санкт-Петербурга.

# %%
sns.regplot(x='city_centers_nearest', 
            y='last_price', 
            data=filter_data[(filter_data.city_centers_nearest_nan_flag != 1) & (filter_data.locality_name == 'Санкт-Петербург')], 
            scatter_kws={'alpha':0.1});

# %% [markdown]
# Видим некоторую зависимость, сформированную, с одной стороны, существенным числом объектов с ценой 3-6 млн., расположенных в пределах 10-18 км от центра, с другой - более дорогими, но малочисленными объектами, расположенными до 10 км от центра. Интересной линией разграничения выглядит отметка в 20 км - около нее объектов практически нет.

# %% [markdown]
# #### Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.

# %% [markdown]
# Поскольку мы оцениваем категориальный признак, посмотрим на столбчатую диаграмму.
#
# Следует заметить, что часть данных по общему числу этажей была заполнена нами, поэтому оценим все данные (в т.ч. с заполненными нами значениями) и данные, в которых изначально не было пропусков. Это связано с тем, что выбранный способ заполнения пропусков мог привести к некоторому перекосу данных в сторону увеличения числа последних этажей.

# %%
# данные с заполненными пропусками
sns.catplot(x='floor_type', y='last_price', kind="bar", data=filter_data);

# %%
# данные без пропусков
sns.catplot(x='floor_type', y='last_price', kind="bar", data=filter_data[filter_data.floors_total_nan_flag != 1]);

# %% [markdown]
# Результаты практически идентичны (это связано с изначально небольшим числом пропусков в признаке floors_total - порядка 0.4%).
#
# Мы видим, что квартиры на первом и последнем этажах стоят значительно меньше (до 20%) квартир, расположенных на любых других этажах, причем квартиры на первом этаже дешевле расположенных на последнем.

# %% [markdown]
# #### Зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# Построим столбцатую диаграмму для дня недели

# %%
sns.catplot(x='meter_price', y='adv_day_of_week', kind="bar", orient='h', aspect=1.5, data=filter_data);

# %% [markdown]
# Зависимости практически нет, можно отметить, что объявления, размещенные в субботу имеют немного меньшую среднюю цену.
#
# Построим столбцатую диаграмму для месяца.

# %%
sns.catplot(x='meter_price', 
            y='adv_month', 
            kind="bar", 
            orient='h', 
            aspect=1.5, 
            data=filter_data);

# %% [markdown]
# Зависимости также невелика. Есть некоторое снижение средней стоимости недвижимости в объявлениях, размещенных в июне, а также некоторое увеличение стоимости объектов, размещенных в апреле.
#
# Построим столбцатую диаграмму для года.

# %%
sns.catplot(x='meter_price', 
            y='adv_year', 
            kind="bar", 
            orient='h', 
            aspect=1.5, 
            data=filter_data);

# %% [markdown]
# Видим пик в 2014 году с достаточно большим разбросом, после чего произошло планомерное снижение и фиксирование цен до 2018 года включительно. В 2019 году вновь начался небольшой рост цен.
#
# Данный признак в общем случае может быть полезен с точки зрения определения тренда, но явного тренда в исследуемых данных не прослеживается.
#
# Для более подробного понимания данных можно дополнительно посмотреть на диаграмму, включающую и месяцы, и годы.

# %%
sns.catplot(y='meter_price', 
            x='adv_year',
            hue='adv_month',
            kind="bar", 
            orient='v', 
            aspect=2.5, 
            data=filter_data);

# %% [markdown]
# Можем частично объяснить причину пика в 2014 году - небольшое количество данных (результат по году зависел всего от 2 месяцев).
#
# В целом, какого-либо значимого тренда в данных не прослеживается: от года к году цены на квартиры меняются из-за каких-либо других факторов, а не сезонности.
#
# Видим, что в данных за 2014 и 2019 гг. отсутствует информация по периодам январь-октябрь и июнь-декабрь соответственно, что также привело к некоторому дисбалансу в оценке результатов зависимости цены от месяца размещения объявления.
#
# Можно подтвердить вывод о том, что существенный вклад при определении цены квартиры данный набор признаков не внесет.

# %% [markdown]
# #### Общий вывод по подразделу
# Мы определили влияние признаков на формирование цены квартир:
# - наибольшее влияние из исследуемых оказывает площадь квартиры: у данных признаков высокий коэффициент корреляции, который говорит о сильной линейной связи между ними. Точность прогноза можно дополнительно повысить, ограничивая данные, например, по локации;
# - достаточно сильная зависимость между ценой и количеством комнат, которая, однако, начинает снижаться для объектов с 4 и большим числом комнат. Отчасти зависимость цены от количества комнат объясняется тем, что у многокомнатных квартир большая площадь, поэтому ориентироваться стоит скорее на площадь помещения;
# - у цены квартиры есть некоторая обратная зависимость от удаленности от центра, однако она не очень велика (коэффициент корреляции -0.33);
# - квартиры на первом и последнем этажах стоят существенно меньше квартир, расположенных на других этажах (вплоть до 20% дисконта);
# - связи между днем, месяцем и годом размещения объявления и ценой квартир не обнаружено: это, с одной стороны, говорит об отсутствии сезонности в продажах недвижимости, с другой - о практически полном отсутствии роста цен на недвижимость на протяжении исследуемого периода (небольшое исключение - пик цен в конце 2014 года и затем резкое их снижение и последующая стагнация).

# %% [markdown]
# ### 10 населённых пунктов с наибольшим числом объявлений (определение населенных пунктов с дорогим и дешевым жильем)

# %% [markdown]
# Выбираем 10 населенных пунктов с наибольшим числом объявлений и находим среднюю стоимость метра жилья в них.

# %%
top_10 = filter_data.groupby('locality_name')['meter_price'].agg(['count', 'mean']).sort_values('count', ascending=False).rename(columns={'count': 'Число объявлений', 'mean': 'Средняя цена метра жилья'}).head(10)
top_10
# Out:
#                    Число объявлений  Средняя цена метра жилья
# locality_name
# Санкт-Петербург               12155             105453.547570
# посёлок Мурино                  463              85414.555579
# посёлок Шушары                  408              78397.908115
# Всеволожск                      350              67195.010136
# Колпино                         311              74957.740856
# посёлок Парголово               305              89974.150564
# Пушкин                          295              99574.233654
# Гатчина                         271              68913.263659
# деревня Кудрово                 257              92373.417070
# Выборг                          199              57694.934473

# %%
top_10.sort_values('Средняя цена метра жилья', ascending=False)['Средняя цена метра жилья'].plot(kind='bar');

# %% [markdown]
# Среди 10 населенных пунктов с самым большим числом объявлений:
# - наиболее высокая стоимость метра жилья в Санкт-Петербурге (105,4 тыс.руб.) и Пушкине (99,5 тыс.руб.);
# - наиболее низкая стоимость метра жилья в Выборге (57,7 тыс. руб.) и Всеволожске (67,2 тыс.руб.).

# %% [markdown]
# ### Определение границ центра Санкт-Петербурга

# %% [markdown]
# Делаем выборку по квартирам в Санкт-Петербурге, убираем из выборки данные, в которых нам было неизвестно расстояние до центра (city_centers_nearest == -1).

# %%
spb_data = filter_data.query('locality_name == "Санкт-Петербург" and city_centers_nearest_nan_flag != 1')

# %%
# добавляем столбец с округленным расстоянием
spb_data['round_distance'] = spb_data['city_centers_nearest'] / 1000
spb_data['round_distance'] = spb_data['round_distance'].round(decimals=0).astype('int')

# %%
spb_data.head(3)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 4             2    10000000       100.0           2018-06-19      2
# 7             5     7915000        71.6           2019-04-18      2
# 9            18     5400000        61.0           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 4            3.03            14        32.00     13         False   False
# 7            2.65            24        41.31     22         False   False
# 9            2.50             9        43.60      7         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 4      False          41.0        0  Санкт-Петербург             31856
# 7      False          18.9        2  Санкт-Петербург             23982
# 9      False           6.5        2  Санкт-Петербург             50898
#
#    city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# ...

# %%
# считаем среднюю цену
spb_distance_price = spb_data.pivot_table(index='round_distance', values='last_price')

# %%
spb_distance_price
# Out:
#                   last_price
# round_distance
# 0               6.650000e+06
# 1               8.006768e+06
# 2               7.800464e+06
# 3               7.224968e+06
# 4               7.411113e+06
# 5               7.504152e+06
# 6               6.971001e+06
# 7               6.635378e+06
# 8               6.518532e+06
# 9               5.525911e+06
# 10              5.316894e+06
# 11              5.287424e+06
# 12              5.314720e+06
# 13              5.523772e+06
# 14              5.241581e+06
# 15              5.279755e+06
# 16              5.092832e+06
# 17              4.827088e+06
# 18              4.595257e+06
# 19              4.829203e+06
# 20              5.942540e+06
# 21              5.416552e+06
# 22              5.195547e+06
# 23              4.749333e+06
# 24              3.822968e+06
# 25              4.088954e+06
# 26              3.973013e+06
# 27              2.250000e+06
# 28              5.026429e+06
# 29              3.650000e+06
# ...

# %%
spb_distance_price.plot();

# %% [markdown]
# Самый большой перепад в средней стоимости происходит на границе 8 и 9 километров (почти на миллион рублей), хотя некоторое снижение начинается уже с 5 километров (но там перепад не так велик - всего 0.5 млн.). Таким образом, к центру города можно отнести квартиры, расположенные до 8 километров от центра включительно.

# %% [markdown]
# ### Анализ квартир в центре города

# %%
spb_data_center = spb_data[spb_data.round_distance <= 8]

# %% [markdown]
# #### Изучение параметров

# %% [markdown]
# **Площадь**

# %%
feature_stat(spb_data_center, 'total_area', need_hist=True)
# Out:
# Признак total_area
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 625
# Минимальное значение: 23.6
# Максимальное значение: 114.8
# Медиана: 60.0
# Среднее: 62.142653455775736
# Мода: 60.0
# Тип данных: float64
# ____________________________________________________________________________________________________
# Гистограмма
# ____________________________________________________________________________________________________

# %% [markdown]
# Среднее практически совпадает с медианой (62 и 60 кв.м. соответственно) и немного больше, чем в общей выборке (54 и 50 кв.м. соответственно). Наиболее частые размеры квартир около 40 метров.
#
# Посмотрим на совмещенную гистограмму данных по центру Петербурга и по общей выборке.

# %%
sns.distplot(spb_data_center['total_area'], label='Центр Петербурга');
sns.distplot(filter_data['total_area'], label='Вся выборка');
plt.legend();

# %% [markdown]
# Видим, что в центре Петербурга распределение больше походит на нормальное - в центре меньше квартир малой площади (до 40 метров) и больше квартир с площадью более 60 метров.

# %% [markdown]
# **Цена**

# %%
feature_stat(spb_data_center, 'last_price', need_hist=True)
# Out:
# Признак last_price
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 584
# Минимальное значение: 2100000.0
# Максимальное значение: 11894400.0
# Медиана: 6900000.0
# Среднее: 7109452.386660222
# Мода: 6500000
# Тип данных: int64
# ____________________________________________________________________________________________________
# Гистограмма
# ____________________________________________________________________________________________________

# %% [markdown]
# Посмотрим на совмещенную гистограмму.

# %%
sns.distplot(spb_data_center['last_price'], label='Центр Петербурга');
sns.distplot(filter_data['last_price'], label='Вся выборка');
plt.legend();

# %% [markdown]
# Видим, что оба набора данных близки к нормальному распределению, при этом можно отметить следующие особенности относительно общей выборки:
# - средняя цена квартир в центре выше цен квартир в среднем по выборке более чем на 2 миллиона (7.11 против 4.84 млн.руб.);
# - дешевых объектов (с ценой менее 2.5 миллионов рублей) в центре практически нет.

# %% [markdown]
# **Число комнат**

# %%
feature_stat(spb_data_center, 'rooms')
# Out:
# Признак rooms
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 7
# Минимальное значение: 0.0
# Максимальное значение: 6.0
# Медиана: 2.0
# Среднее: 2.193813436442726
# Мода: 2
# Тип данных: int64
# ____________________________________________________________________________________________________

# %%
my_hist(spb_data_center, 'rooms', bins=7)

# %%
plt.hist([spb_data_center['rooms'], filter_data['rooms']], density=True, label=['Центр Петербурга', 'Вся выборка']);
plt.legend();

# %% [markdown]
# Среднее и медиана практически одинаковы и соответствуют аналогичным данным из общей выборки.
#
# Однако сами данные несколько различаются. В общей выборке чаще всего (мода) встречаются однокомнатные квартиры, а в центре - двухкомнатные.

# %% [markdown]
# **Высота потолков**

# %%
feature_stat(spb_data_center[spb_data_center.ceiling_height_nan_flag != 1], 'ceiling_height', need_hist=True)
# Out:
# Признак ceiling_height
# ____________________________________________________________________________________________________
# Кол-во пропусков (доля): 0 (0.0%)
# Кол-во уникальных значений: 64
# Минимальное значение: 2.4
# Максимальное значение: 3.2
# Медиана: 2.875
# Среднее: 2.8565139116202944
# Мода: 3.0
# Тип данных: float64
# ____________________________________________________________________________________________________
# Гистограмма
# ____________________________________________________________________________________________________

# %%
sns.distplot(spb_data_center[spb_data_center.ceiling_height_nan_flag != 1]['ceiling_height'], label='Центр Петербурга');
sns.distplot(filter_data[filter_data.ceiling_height_nan_flag != 1]['ceiling_height'], label='Вся выборка');
plt.legend();

# %% [markdown]
# Медиана близка к среднему, при этом они примерно на 20 сантиметров больше аналогичных значений по общей выборке (2.87, 2.86 против 2.64, 2.68). В центре большее число квартир имеет высокие потолки (самое частое значение для центра - 3 метра, для выборки в целом - 2.5 метра).

# %% [markdown]
# #### Факторы, которые влияют на стоимость квартиры

# %% [markdown]
# **Число комнат**

# %%
spb_data_center[['rooms', 'last_price']].corr()
# Out:
#               rooms  last_price
# rooms       1.00000     0.43832
# last_price  0.43832     1.00000

# %% [markdown]
# Коэффициент корреляции практически такой же, как в целом по выборке (0.438 против 0.42).
#
# Построим стобчатую диаграмму.

# %%
sns.catplot(x='rooms', y='last_price', kind="bar", data=spb_data_center);

# %% [markdown]
# На диаграмме видна чуть более ровная зависимость цены от числа комнат по сравнению с выборкой в целом, однако для 5 и 6-комнатных квартир мы видим большой доверительный интервал, что также свидетельствует о том, что для данных объектов основными становятся дополнительные параметры.
#
# Можно сказать, что количество комнат одинаково важно как для центра Петербурга, так и для других исследуемых локаций.

# %% [markdown]
# **Этаж**

# %%
sns.catplot(x='floor_type', y='last_price', kind="bar", data=spb_data_center[spb_data_center.floors_total_nan_flag != 1]);

# %% [markdown]
# В общей выборке стоимость квартир на первом и последнем этажах была существенно ниже стоимости квартир на других этажах. Для центра Санкт-Петербурга квартиры на последнем этаже оцениваются практически так же, как и квартиры на других этажах (за исключеним первого). Это может быть связано с наличием какого-либо особенного жилья на последних этажах, характерного только для Петербурга (лофты, квартиры с выходом на крышу, может быть жители просто любят вид с высоты - корректные предположения зависят от более подробного погружения в рынок недвижимости Петербурга).
#
# Для первого этажа дисконт составляет порядка 20% (как и для общей выборки).

# %% [markdown]
# **Удаленность от центра**

# %%
# посмотрим на коэффициент корреляции
spb_data_center[spb_data_center.city_centers_nearest != -1][['city_centers_nearest', 'last_price']].corr()
# Out:
#                       city_centers_nearest  last_price
# city_centers_nearest              1.000000   -0.180261
# last_price                       -0.180261    1.000000

# %% [markdown]
# Фактор перестал был значимым относительно общей выборки (-0.18 против -0.33). Это связано с тем, что мы уже рассматриваем центр города, поэтому влияние данного фактора становится менее значимым относительно всей выборки.

# %%
sns.regplot(x='city_centers_nearest', 
            y='last_price', 
            data=spb_data_center[spb_data_center.city_centers_nearest != -1], 
            scatter_kws={'alpha':0.2});

# %% [markdown]
# На графике также видим существенный разброс значений, что подтверждает отсутствие значимости данного фактора для квартир в центре.

# %% [markdown]
# **Дата размещения объявления**

# %% [markdown]
# В общей выборке дата размещения объявления практически никак не влияла на цену. Построим столбчатые диаграммы для центра города.

# %%
sns.catplot(x='last_price', y='adv_day_of_week', kind="bar", orient='h', aspect=1.8, data=spb_data_center);

# %% [markdown]
# Зависимости практически нет, можно отметить, что объявления, размещаемые с в воскресенье имеют немного большую среднюю цену относительно других дней (в пределах 5%).
#
# Построим столбцатую диаграмму для месяца.

# %%
sns.catplot(x='meter_price', 
            y='adv_month', 
            kind="bar", 
            orient='h', 
            aspect=1.8, 
            data=spb_data_center);

# %% [markdown]
# Можно выделить минимум и максимум средних значений - в марте размещаются объявления с самыми дорогими квартирами, в июне - с самыми дешевыми (разница между минимумом и максимумом порядка 10%). В общей выборке минимальные значения также приходились на июньские объявления, а максимальные - на апрель.
#
# Построим столбцатую диаграмму для года.

# %%
sns.catplot(x='meter_price', 
            y='adv_year', 
            kind="bar", 
            orient='h', 
            aspect=1.7, 
            data=spb_data_center);

# %% [markdown]
# Видим небольшой слабый тренд на повышение цены, немного ускоряющийся в 2019 году (рост цен за пять лет в пределах 10%).
#
# Посмотрим на диаграмму, включающую и месяцы, и годы.

# %%
sns.catplot(y='meter_price', 
            x='adv_year',
            hue='adv_month',
            kind="bar", 
            orient='v', 
            aspect=2.5, 
            data=spb_data_center);

# %% [markdown]
# В данных видим большой пик в феврале 2015 и августе 2016 года. Возможно они связаны с малым числом размещенных объектов.

# %%
spb_data_center.query('adv_year == 2015 and adv_month == 2')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 7731             9     7700000        42.0           2015-02-26      1
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 7731            2.65             7         18.0      4         False   False
#
#       open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 7731      False          11.0        0  Санкт-Петербург             32685
#
#       city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 7731                  6131                 0              0                 1
#
#       ponds_nearest  days_exposition  ceiling_height_nan_flag  \
# 7731            357              480                        1
#
#       floors_total_nan_flag  living_area_nan_flag  is_apartment_nan_flag  \
# 7731                      0                     0                      1
#
#       kitchen_area_nan_flag  balcony_nan_flag  locality_name_nan_flag  \
# ...

# %%
spb_data_center.query('adv_year == 2016 and adv_month == 8')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 736              8    10690000        86.9           2016-08-05      2
# 1876            12    11490000        74.0           2016-08-31      3
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 736             2.65             6         50.5      4         False   False
# 1876            2.70             5         45.4      5         False   False
#
#       open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 736       False          12.5        0  Санкт-Петербург             25323
# 1876      False           9.8        1  Санкт-Петербург             20717
#
#       city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 736                   5741                 2            393                 0
# 1876                   936                 3            333                 2
#
# ...

# %%
# проверим причину колебаний в 2015 и 2016 гг. - вероятно просто было мало объявлений
spb_data_center.query('adv_year <= 2016')['adv_year'].count()
# Out:
# 311

# %%
# проверяем сколько было объявлений всего
spb_data_center.shape[0]
# Out:
# 2069

# %% [markdown]
# В феврале 2015 было всего одно объявление, в августе 2016 размещено 2 достаточно дорогих объекта, что объясняет пики.
#
# В 2017-2019 гг. средние цены незначительно колебались от месяца к месяцу, максимально неустойчив рынок был в 2015 и 2016 гг. (вероятно это связано с относительно низким числом объявлений в этот период: всего порядка 16%).

# %% [markdown]
# #### Вывод по подразделу

# %% [markdown]
# Мы провели анализ площади, цены, числа комнат и высоты потолков в центре Петербурга и сравнили их с общей выборкой. Из проведенного анализа можно сделать следующие выводы:
# 1. Площадь квартир в центре Петербурга в среднем выше площади квартир в целом по выборке (62 и 54 метра соответственно). В центре Петербурга, в отличии от общей выборки, достаточно низка доля квартир небольшой площади (менее 40 метров), доля квартир более 60 метров в центре Петербурга выше, чем в целом по выборке.
# 2. Цены на квартиры в центре города существенно выше, чем в целом по выборке (7.12 против 4.84 млн.руб.), при этом дешевых квартир (дешевле 2.5 млн.) в центре практически нет.
# 3. Для центра города характерны не менее чем двухкомнатные квартиры. Они же составляют наиболее часто выставляемые на продажу объекты. Во всей выборке наиболее часто встречаются однокомнатные квартиры.
# 4. Высота потолков в квартирах центра города существенно выше, чем в целом по выборке (2.86 против 2.68), наиболее часто в центре встречаются квартиры с высотой потолков 3 метра, для всей выборки самым частым значением является 2.5 метра.
#
# Оценивая факторы, которые влияют на цену квартир в центре, можно сделать следующие выводы:
# 1. Кол-во комнат напрямую влияет на цену квартиры в Петербурге (как и для общей выборки), однако скорее это связано с большей площадью многокомнатных квартир.
# 2. Самые дешевые квартиры в центре города расположены на первом этаже (разница в цене между первым и любым другим этажом доходит до 20%), однако, в отличии от общей выборки, где квартиры на последнем этаже также оцениваются с большим дисконтом (до 15%), квартиры в центре, расположенные на последнем этаже, стоят дешевле всего около 5% (мы предположили, что это может быть связано с тем, что на последних этажах в центре города могут располагаться лофты, объекты с выходом на крышу или иными преимуществами).
# 3. Удаленность от центра, как и предполагалось, не влияет (коэффициент корреляции -0.18) на цены в центре Петербурге (фактически мы и так находимся в зоне максимальных цен на квартиры).
# 4. День недели практически не влияет на цены (как и для общей выборки), небольшой пик заметен для воскресных объявлений (превышение над другими днями в пределах 5%). Для месяца можно отметить определенные пики цены в объявлениях, размещенных в марте, и минимумы для июньских объявлений. В разрезе года объявления заметен незначительный повышательный тренд, немного ускорившийся к концу исследуемого периода (в 2019 году): общий рост цен за все время в пределах 10%.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Мы выполнили исследование рынка недвижимости Санкт-Петербурга и ближайших к нему населенных пунктов на основании данных за период с ноября 2014 года по май 2019 года.
#
# По результатам проведенного исследования были сделаны следующие выводы:
# 1. В данных представлена недвижимость из 364 населенных пунктов, при этом большая часть объектов (более 66%) расположена непосредственно в Санкт-Петербурге. К популярным населенным пунктам также относятся (в порядка убывания числа объявлений) посёлок Мурино, посёлок Шушары, Всеволожск, Колпино, посёлок Парголово, Пушкин, Гатчина, деревня Кудрово, Выборг.
# 2. Из самых популярных населенных пунктов наиболее высокая стоимость метра жилья в Санкт-Петербурге (105,4 тыс.руб.) и Пушкине (99,5 тыс.руб.), наиболее низкая стоимость метра жилья в Выборге (57,7 тыс. руб.) и Всеволожске (67,2 тыс.руб.).
# 3. При создании объявлений многие люди не заполняют часть необязательных на их взгляд параметров (количество балконов, принадлежность объекта недвижимости к апартаментам, жилая и кухонная площадь и т.д.).
# 4. Средний размер продаваемой квартиры - 54.55 метра, в центре города - 62.14 метра.
# 5. Средняя цена продаваемой квартиры - 4.84 миллиона рублей, в центре города - 7.11 млн.руб.
# 6. Чаще всего люди продают однокомнатные квартиры, в центре города - двухкомнатные.
# 7. Средняя высота потолков составляет 2.68 метра, в центре города - 2.86 метра, при этом наиболее часто в центре встречаются квартиры с высотой потолков 3 метра, для всех данных самым частым значением является 2.5 метра.
# 8. Больше всего на цену квартиры влияют ее площадь и количество комнат, этаж (квартиры на первом этаже существенно дешевле - до 20%, квартиры на последнем этаже также стоят дешевле во всех локациях, за исключением центра города), а также расположение (квартиры в центре существенно дороже).
# 9. Также для выборок была обнаружена некоторая взаимосвязь месяца размещения объявления с ценой квартиры: максимальная цена у объектов, размещенных в марте (для центра города) и апреле (для всей выборки), минимальная у объектов, размещенных в июне (разница между минимумом и максимумом порядка 10%).
# 10. Для центра Санкт-Петербурга также была обнаружена незначительная взаимосвязь в дне размещения объявления (квартиры, выставленные на продажу в воскресенье, немного (в пределах 5%) дороже других).
# 11. Для центра города характерен незначительный повышательный тренд в цене квартир, ускоряющийся ближе к концу периода (в пределах 10%).
#
# Сводная таблица результатов исследования для выборки в целом и центра Санкт-Петербурга представлена ниже.

# %%
result = pd.DataFrame([[62.14, 54.55], 
                       [7.11, 4.84], 
                       [2.86, 2.68],
                       [3.00, 2.50],
                       [2.2, 2.05],
                       [2, 1],
                       ['март', 'апрель'],
                       ['июнь', 'июнь']], 
                      columns=['Центр Петербурга', 'Вся выборка'],
                      index=['Средняя площадь, кв.м.', 
                             'Средняя цена, млн.руб.', 
                             'Средняя высота потолков, м.', 
                             'Самая распространненная высота потолков, м.',
                             'Среднее кол-во комнат, шт.',
                             'Самое распространенное количество комнат, шт.',
                             'Месяц размещения самых дорогих квартир',
                             'Месяц размещения самых дешевых квартир'])
result
# Out:
#                                               Центр Петербурга Вся выборка
# Средняя площадь, кв.м.                                   62.14       54.55
# Средняя цена, млн.руб.                                    7.11        4.84
# Средняя высота потолков, м.                               2.86        2.68
# Самая распространненная высота потолков, м.                  3         2.5
# Среднее кол-во комнат, шт.                                 2.2        2.05
# Самое распространенное количество комнат, шт.                2           1
# Месяц размещения самых дорогих квартир                    март      апрель
# Месяц размещения самых дешевых квартир                    июнь        июнь
